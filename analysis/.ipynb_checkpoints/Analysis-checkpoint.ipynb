# %% [raw]
# This notebook will do the following:
#     1) Initialize 3D coordinates from adjacency matrix.
#     2) Efficiently convert 3D coordinated to adjacency matrix.
#     3) Efficiently evaluate RMSE between original adj matrix values and
#     4) Implement optimization algorithm for moving 3D coordinates to minimize objective function (loss).
#         a) probably SGD
#         b) genetic algorithms
#     5) Run optimization algorithm on dataset and store each intermediate 3D coordinates
#     6) Evaluate performance

# %%
import pandas as pd
import numpy as np
import time as t
import datetime
import itertools
import os
from scipy.sparse import lil_matrix
import operator
import math
import warnings

# %%
# this is a numpy matrix of size (num_vertex, 3) which is the true positions in geographic space
location_array = np.array([[ 33.77636,  -84.397824],
                             [ 33.772428, -84.392709],
                             [ 33.77036,  -84.387824],
                             [ 33.765,    -84.38    ]])
# number of vertices
num_vertex = location_array.shape[0]

# this is a numpy matrix of size (num_vertex, num_vertex) which is populated by time between each location
original_adjacency_matrix = lil_matrix((num_vertex,num_vertex), dtype = np.float32)
original_adjacency_matrix[0,1] = 75
original_adjacency_matrix[1,0] = 75
original_adjacency_matrix[0,2] = 50
original_adjacency_matrix[2,0] = 50
original_adjacency_matrix[3,0] = 50
original_adjacency_matrix.todense()
# Out:
# matrix([[ 0., 75., 50.,  0.],
#         [75.,  0.,  0.,  0.],
#         [50.,  0.,  0.,  0.],
#         [50.,  0.,  0.,  0.]], dtype=float32)

# %%
# convert adjacency_matrix to an initial "guess" at 3D coordinates. We want 3D coordinates to have minimal Z components
# please make Z = 0 for all points, and all x and y be seperated by average time difference (this is for mesh input)
# num_columns and num_rows are needed to know where everything is related to.
# (avg time difference * perturb) is sampled from normal distribution and added to all coordinates

def initialize_coordinates(adjacency_matrix, num_rows, num_columns, perturb = 0):
    # make coordinates matrix
    if num_rows * num_columns != adjacency_matrix.shape[0] or adjacency_matrix.shape[0] != adjacency_matrix.shape[1]:
        raise ValueError("Your dimensions are wrong! Get it together breh")
    
    coordinates = np.zeros(shape = (adjacency_matrix.shape[0], 3))
    cx = adjacency_matrix.tocoo()
    
    # find average time seperation
    weight = 0
    counter = 0
    for i,j,v in zip(cx.row, cx.col, cx.data):
        counter += 1
        weight += v
    avg = weight/counter
    
    # make mesh to find where each coordinate should begin
    mesh = np.zeros(shape = (num_rows, num_columns, 3))
    for i,j in itertools.product(range(num_rows), range(num_columns)):
        mesh[i,j,0] = i*avg
        mesh[i,j,1] = j*avg
    
    # set coordinates from mesh and return
    for i,j in itertools.product(range(num_rows), range(num_columns)):
        index = i * num_columns + j
        coordinates[index,:] = mesh[i,j,:]
    
    # add noise
    noise = np.random.normal(size = coordinates.shape) * perturb * avg
    coordinates += noise
    
    return coordinates

# %%
# convert our 3D coordinates into a matrix representation,
# where x and y and interpolated from their nearest locations as well as z

from scipy.interpolate import interp2d

def interpolate_mesh(coordinates, num_points= 100, kind = 'cubic'):
    # make f, our function which estimates the z or height at all positions
    f = interp2d(coordinates[:,0], coordinates[:,1], coordinates[:,2], kind=kind)
    
    # make the new mesh
    min_bounds = np.min(coordinates, axis = 0)
    max_bounds = np.max(coordinates, axis = 0)
    x_new = np.linspace(min_bounds[0], max_bounds[0], num=num_points)
    y_new = np.linspace(min_bounds[1], max_bounds[1], num=num_points)
    xx_new, yy_new = np.meshgrid(x_new, y_new)
    zz_new = f(x_new, y_new)
    
    arr = np.empty((num_points, num_points, 3))
    arr[:,:,0] = xx_new
    arr[:,:,1] = yy_new
    arr[:,:,2] = zz_new
    return arr

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

def plot_coordinates(coordinates,rstride=3, cstride=3, kind = 'cubic'):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    arr = interpolate_mesh(coordinates, kind = kind)
    X = arr[:,:,0]
    Y = arr[:,:,1]
    Z = arr[:,:,2]
    
    # Plot a basic wireframe.
    #ax.plot_wireframe(X, Y, Z, rstride=rstride, cstride=cstride)
    
    # Plot the points on top of this
    ax.scatter(coordinates[:,0], coordinates[:,1], coordinates[:,2])
    plt.show()

# %%
# this is the 3D rotation matrix implemented
def rotation_matrix(axis, theta):
    """
    Return the rotation matrix associated with counterclockwise rotation about
    the given axis by theta radians.
    """
    axis = np.asarray(axis)
    axis = axis / math.sqrt(np.dot(axis, axis))
    a = math.cos(theta / 2.0)
    b, c, d = -axis * math.sin(theta / 2.0)
    aa, bb, cc, dd = a * a, b * b, c * c, d * d
    bc, ad, ac, ab, bd, cd = b * c, a * d, a * c, a * b, b * d, c * d
    return np.array([[aa + bb - cc - dd, 2 * (bc + ad), 2 * (bd - ac)],
                     [2 * (bc - ad), aa + cc - bb - dd, 2 * (cd + ab)],
                     [2 * (bd + ac), 2 * (cd - ab), aa + dd - bb - cc]])

# %%
# input and rotation, can change if you want to convince urself
v = np.array([1,0,0])
axis = np.array([0,1,0])
theta = math.pi/4

# vector after rotation
rot_mat = rotation_matrix(axis, theta)
w = np.dot(rotation_matrix(axis, theta), v)

# plot it
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x,y,z = [0,0], [0,0], [0,0]
x_j,y_j,z_j = [v[0],w[0]], [v[1],w[1]], [v[2],w[2]]
ax.quiver(x,y,z,x_j,y_j,z_j, length=0.05, normalize=True)
plt.show()

# %%
coordinates = initialize_coordinates(original_adjacency_matrix, 2, 2, .1)
rot_coordinates = np.transpose(rot_mat@np.transpose(coordinates))
plot_coordinates(coordinates, kind = 'linear')
plot_coordinates(rot_coordinates, kind = 'linear')
coordinates
# Out:
# array([[ 1.25161138,  1.65733168,  0.18045132],
#        [ 1.8832158 , 52.95219854,  1.83666517],
#        [60.2148933 ,  5.40114316, -7.52288096],
#        [55.25206934, 67.7282132 ,  2.27405635]])

# %%
# take 3D coordinates and original adjacency_matrix and return adj mat from 3D coords
def adjacency_matrix_from_coords(coordinates, adjacency_matrix):
    if len(coordinates.shape) == 1:
        coordinates = coordinates.reshape((int(coordinates.shape[0]/3),3))
    # find the points in the adjacency matrix that are not 0
    ret_coords = adjacency_matrix.copy()
    cx = adjacency_matrix.tocoo()
    for i,j in zip(cx.row, cx.col):
        ret_coords[i,j] = np.linalg.norm(coordinates[i]-coordinates[j])
    return ret_coords

# %%
# take 3D coordinates and original adjacency_matrix and return RMSE 
def rmse(coordinates, adjacency_matrix):
    # reshape if necessary (because of how scipy does its computations)
    if len(coordinates.shape) == 1:
        coordinates = coordinates.reshape((int(coordinates.shape[0]/3),3))
    
    # initialize counters
    rmse, counter = 0, 0
    
    # calculate loss
    cx = adjacency_matrix.tocoo()
    for i,j,true_dist in zip(cx.row, cx.col, cx.data):
        dist = np.linalg.norm(coordinates[i]-coordinates[j])
        rmse += (dist - true_dist)**2
        counter += 1
    rmse = (rmse/counter)**.5
    return rmse

# gradient loss with respect to the function of sqrt(sum((distance - distance_actual)^2))
def grad_rmse(coordinates, adjacency_matrix):
    # reshape if necessary (because of how scipy does its computations)
    if len(coordinates.shape) == 1:
        coordinates = coordinates.reshape((int(coordinates.shape[0]/3),3))
    
    # make the gradient numpy array
    gradient = np.zeros_like(coordinates)
    
    # calculate all distances squared for the current coordinates and square original distances
    adjacency_matrix_curr = adjacency_matrix.copy()
    A_coo = adjacency_matrix.tocoo()
    # make a dictionary which maps all indices in row i to cols which have an existing edge
    pos_edges = dict()
    for i,j in zip(A_coo.row, A_coo.col):
        adjacency_matrix_curr[i,j] = np.linalg.norm(coordinates[i,:]-coordinates[j,:])
        if i in pos_edges: pos_edges[i].append(j)
        else: pos_edges[i] = [j]
    A_coo = adjacency_matrix.tocoo()
    A_curr_coo = A_coo.copy()
    
    # now use the formula for gradient, yes i derived this and yes it was a pain in the ass
    for i in range(coordinates.shape[0]):
        curr_grad = np.zeros(shape = 3)
        for k in pos_edges[i]:
            t1 = (adjacency_matrix_curr[i,k] - adjacency_matrix[i,k])
            t2 = .5 * (adjacency_matrix_curr[i,k]**2 / len(pos_edges[i]))**-.5
            t3 = 2 * (coordinates[i] - coordinates[k])
            curr_grad += t1 * t2 * t3
        s = np.sign(curr_grad)
        
        curr_grad = .5 * (curr_grad * s)**-.5 
        gradient[i,:] = curr_grad * s
    
    return gradient.reshape((coordinates.shape[0]*coordinates.shape[1]))

# %%
# loss with respect to the function of sum(distance^2 - distance_actual^2)/|Edges|
def mse_dist_squared(coordinates, adjacency_matrix):
    # reshape if necessary (because of how scipy does its computations)
    if len(coordinates.shape) == 1:
        coordinates = coordinates.reshape((int(coordinates.shape[0]/3),3))
    
    # initialize counters
    mse, counter = 0, 0
    
    # calculate loss
    cx = adjacency_matrix.tocoo()
    for i,j,true_dist in zip(cx.row, cx.col, cx.data):
        dist_vec = coordinates[i]-coordinates[j]
        dist_squared = np.inner(dist_vec, dist_vec)
        mse += (dist_squared - true_dist**2)**2
        counter += 1
    mse = mse/counter
    return mse

# gradient loss with respect to the function of sum(distance^2 - distance_actual^2)
def grad_mse(coordinates, adjacency_matrix):
    # reshape if necessary (because of how scipy does its computations)
    if len(coordinates.shape) == 1:
        coordinates = coordinates.reshape((int(coordinates.shape[0]/3),3))
    
    # make the gradient numpy array
    gradient = np.zeros_like(coordinates)
    
    # calculate all distances squared for the current coordinates and square original distances
    adjacency_matrix_squared = adjacency_matrix.copy()
    adjacency_matrix_curr = adjacency_matrix.copy()
    A_coo = adjacency_matrix.tocoo()
    # make a dictionary which maps all indices in row i to cols which have an existing edge
    pos_edges = dict()
    for i,j in zip(A_coo.row, A_coo.col):
        dist_vec = coordinates[i,:]-coordinates[j,:]
        adjacency_matrix_curr[i,j] = np.inner(dist_vec, dist_vec)
        adjacency_matrix_squared[i,j] = adjacency_matrix_squared[i,j] ** 2
        if i in pos_edges: pos_edges[i].append(j)
        else: pos_edges[i] = [j]
    A_coo = adjacency_matrix.tocoo()
    A_curr_coo = A_coo.copy()
    
    # now use the formula dL/dc_ij = 4/|e_ik| sum_e_ik(dist^2 - dist_curr^2)(c_ij - c_kj)
    for i in range(coordinates.shape[0]):
        for k in pos_edges[i]:
            gradient[i,:] += (adjacency_matrix_curr[i,k] - adjacency_matrix_squared[i,k])*\
                                (coordinates[i,:] - coordinates[k,:])
        gradient[i,:] = (4./len(pos_edges[i])) * gradient[i,:]
    
    return gradient.reshape((coordinates.shape[0]*coordinates.shape[1]))

# %%
rmse(coordinates, original_adjacency_matrix)
# Out:
# 22.604009533870702

# %%
rmse(rot_coordinates, original_adjacency_matrix)
# Out:
# 22.604009533870702

# %%
grad_rmse(coordinates, original_adjacency_matrix)
# Out:
# array([-0.1386837 ,  0.0875586 ,  0.29709297, -0.92634639, -0.10279193,
#        -0.572055  ,  0.16237038,  0.64437791, -0.44921921,  0.10571914,
#         0.09557566,  0.53691431])

# %%
mse_dist_squared(coordinates, original_adjacency_matrix)
# Out:
# 8599488.62495919

# %%
mse_dist_squared(rot_coordinates, original_adjacency_matrix)
# Out:
# 8599488.624959191

# %%
grad_mse(coordinates, original_adjacency_matrix)
# Out:
# array([-120048.10077233,  298952.36087254,   26083.85984655,
#          -7555.74371212, -613629.12115415,  -19812.91916785,
#         247651.94525677,   15724.39940908,  -32354.80052526,
#        1033740.25899877, 1264806.49904868,   40078.24911232])

# %%
# take 3D coordinates and original adjacency_matrix and return new adjacency_matrix

def coordinates_adjacency(coordinates, original_adjacency_matrix):
    adjacency_matrix = lil_matrix(original_adjacency_matrix.shape, dtype = np.float32)
    cx = original_adjacency_matrix.tocoo()
    for i,j in zip(cx.row, cx.col):
        pt_one = coordinates[i]
        pt_two = coordinates[j]
        distance = ((pt_one[0] - pt_two[0])**2 + (pt_one[1] - pt_two[1])**2 + (pt_one[2] - pt_two[2])**2)**.5
        adjacency_matrix[i,j] = distance
    return adjacency_matrix

# %%
new_adjacency_matrix = coordinates_adjacency(coordinates, original_adjacency_matrix)
new_adjacency_matrix.todense()
# Out:
# matrix([[ 0.      , 51.325485, 59.582096,  0.      ],
#         [51.325485,  0.      ,  0.      ,  0.      ],
#         [59.582096,  0.      ,  0.      ,  0.      ],
#         [85.356865,  0.      ,  0.      ,  0.      ]], dtype=float32)

# %% [markdown]
# turns out for our particular problem we are trying to minimize the following equation:
#
# V is the set of coordinate points
# $N_{pi}$ is the neighborhood for a specific coordinate point $p_{i}$
# A is the QUERIED or TRUE adjacency matrix we wish to emulate without solution
#
# $\sqrt{\Sigma_{p_{i}}^{V}\Sigma_{n_{j}}^{N_{pi}}(\sqrt{\Sigma(p_{i} - n_{j})^2} - A[n_j,p_i])^2}/\sqrt{\text{num vertex}}$
#
# The "english" version of this is the minimal root mean squared error between our distance and the true distance. The term below is simply the distance equation between a point and its neighbors.
#
# $\sqrt{\Sigma(p_{i} - n_{j})^2}$
#
# Using A' to represent the Ajacency Matrix we calculate above (i.e. from our current coordinates),
# the above can be written quite simply as:
#
# $\sqrt{\Sigma_{p_{i}}^{V}\Sigma_{n_{j}}^{N_{pi}}(A'[i,j]-A[i,j])^2}/\sqrt{\text{num vertex}}$
#
# or even more simply,
#
# $\sqrt{\Sigma_{i,j}^{A}(A'[i,j]-A[i,j])^2}/\sqrt{\text{num vertex}}$
#
# why not again?
#
# $RMSE(A',A)$
#
#
# This above equation can be minimized by changing where each coordinate lies. In the sgd function below, we are simply calculating an analytical approx. for the gradient for each point in turn, and then updating each point by some learning rate.
# ***A key efficiency consideration would be to not calulate change in RMSE using all points as RMSE by changing one point only effects the neighbors of this point***
#
# Another option to find ideal coordinate positions would be to analytically/explicity solve the above equation. This would be done by taking the partial derivative with respect to every xyz coordinates, finding where the gradient is 0 and being finished. Unfortunately, this solvation is not convex (i.e. only one minimum) if we look at RMSE(A',A), ***but to find x,y,z that minimizes RMSE(A'A) by changing only one point is actually convex.*** I will prove this below, its not super involved math but if it scares you feel free to ignore it. Basically what this equation gives us is a way to calculate the best position to put a x,y,x coordinate to minimize RMSE by only changing that coordinate.
#
# minimize:
#
# $\sqrt{\Sigma_{p_{i}}^{V}\Sigma_{n_{j}}^{N_{pi}}(\sqrt{\Sigma(p_{i} - n_{j})^2} - A[n_j,p_i])^2}/\sqrt{\text{num vertex}}$
#
# look at minimizing RMSE for one point (i), we can ignore the num vertex as it is a constant, and the square root is actually also unneeded, as the absolute minima for MSE is also the absolute minima for RMSE:
#
# $\Sigma_{j}^{N_{i}}(\sqrt{\Sigma(p_{i} - n_{j})^2} - A[n_j,p_i])^2$
#
# now take the derivative with respect to x
#
# $\Sigma_{j}^{N_{i}}2(\sqrt{\Sigma(p_{i} - n_{j})^2} - A[n_j,p_i])$

# %%
# turns our for our particular problem we are trying to minimize the following equation, which sh

def explicit_solvation(coordinates, adjacency_matrix):
    raise ValueError()

# %%
# Simplified RMSE difference between initial and final to make the process computationally easier for calculating partial derivatives 
def RMSEdiff(coordinates, adjacency_matrix, vertex_index, delta, xyz_index):
    
    cx = adjacency_matrix.getrowview(vertex_index).tocoo()
    RMSEinitial = 0
    RMSEdiff = 0
    counter = 0
    deltaX = 0
    deltaY = 0
    deltaZ = 0
    
    # xyz_index is the index of whatever value needs to be changed
    if(xyz_index == 0):
        deltaX = delta
    elif(xyz_index == 1):
        deltaY = delta
    elif(xyz_index == 2):
        deltaZ = delta
    
    for row,col,data in zip(cx.row, cx.col, cx.data):
        # find the distance between the two coordinates, as well as the distance if the delta changes x, y, or z
        distanceinitial = ((coordinates[col, 0] - coordinates[row, 0])**2
                            + (coordinates[col, 1] - coordinates[row, 1])**2
                            + (coordinates[col, 2] - coordinates[row, 2])**2) **.5
        
        distancewithdelta = ((coordinates[col, 0] - (coordinates[row, 0] + deltaX))**2
                            + (coordinates[col, 1] - (coordinates[row, 1] + deltaY))**2
                            + (coordinates[col, 2] - (coordinates[row, 2] + deltaZ))**2) ** .5
        
        #print(distancewithdelta, distanceinitial)
        # then, find the RMSE of the predicted point (coordinate) and the given point (adjacency) for both the initial and final
        RMSEinitial += (distanceinitial - data)**2
        RMSEdiff += (distancewithdelta - data)**2
        counter += 1
    
    if counter != 0:
        ret_val = ((RMSEdiff-RMSEinitial)/counter)
        return ret_val
    else:
        return 0

# %%
# take 3D coordinates and return updated 3D coordinates using SGD
# coordinates is a nx3 numpy array
# adjacency_matrix is a nxn lil matrix

def sgd(coordinates, adjacency_matrix, delta = 1e-3, alpha = 1e-5):
    new_coordinates = np.copy(coordinates)
    # Alpha + Delta are Hyperparameters (ones that you can change)
    alpha = 0.01
    # Not sure if #1, deltas should be different, and #2, if they should gradually become lower
    # this can be played around with
    deltaX = delta
    deltaY = delta
    deltaZ = delta
    # main iterator that goes through each point updating their x, y, and z value
    for vertex_index in range(coordinates.shape[0]):
        new_coordinates[vertex_index, 0] -= (alpha/delta * (RMSEdiff(new_coordinates,
                                                               adjacency_matrix, vertex_index, deltaX, 0)))
        new_coordinates[vertex_index, 1] -= (alpha/delta * (RMSEdiff(new_coordinates,
                                                               adjacency_matrix, vertex_index, deltaY, 1)))
        new_coordinates[vertex_index, 2] -= (alpha/delta * (RMSEdiff(new_coordinates,
                                                               adjacency_matrix, vertex_index, deltaZ, 2)))
    # Not sure if we want to recreate new coordinates
    return new_coordinates

# %%
new_coordinates = sgd(coordinates, original_adjacency_matrix)
new_coordinates
plot_coordinates(new_coordinates, kind = 'linear')

# %%
# run full simulation and return lists of coordinates and rmse

def simulation(adjacency_matrix, num_rows, num_columns, num_iterations = 1e4, delta = 1e-3, alpha = 1e-5, kind = 'cubic'):
    
    coordinates_ls, rmse_ls = [], []
    
    # initialize coordinates and rmse
    coordinates_ls.append(initialize_coordinates(adjacency_matrix,num_rows,num_columns))
    rmse_ls.append(rmse(coordinates_ls[-1], adjacency_matrix))
    
    # continue to add coordinates and rmse
    for i in range(int(num_iterations)):
        if i % 100 == 0:
            plot_coordinates(coordinates_ls[-1], rstride=30, cstride=30, kind = kind)
            print(rmse_ls[-1])
        
        coordinates_ls.append(sgd(coordinates_ls[-1], adjacency_matrix, delta = 1e-3, alpha = 1e-5))
        rmse_ls.append(rmse(coordinates_ls[-1], adjacency_matrix))
    
    return coordinates_ls, rmse_ls

# %%
# dump the simulation into a pandas df and then a csv (not done yet)

coordinates_ls, rmse_ls = simulation(original_adjacency_matrix, 2, 2, num_iterations = 100, kind = 'linear')

"""df = pd.DataFrame()
path = os.path.join(os.getcwd(), "..")
path = os.path.join(path, "dataset")
path = os.path.join(path, "simulation.csv")
#df.to_csv(path)"""
# Out:
# 19.311750960290627
# 'df = pd.DataFrame()\npath = os.path.join(os.getcwd(), "..")\npath = os.path.join(path, "dataset")\npath = os.path.join(path, "simulation.csv")\n#df.to_csv(path)'

# %%
# now we will try it on our data!!

def csv_graph(csv, value = "Traffic Time"):
    
    df = pd.read_csv(csv)
    
    locations = set()
    for row in range(df.shape[0]):
        loc = tuple([df["Origin Latitude"][row],df["Origin Longitude"][row]])
        locations.add(loc)
    locations = list(locations)
    
    num_vertex = len(locations)
    location_array = np.zeros(shape = (num_vertex, 2))
    adjacency_matrix = lil_matrix((num_vertex,num_vertex), dtype = np.float32)

    locations.sort(key = operator.itemgetter(0, 1))
    for i in range(len(locations)):
        location_array[i,0] = locations[i][0]
        location_array[i,1] = locations[i][1]
        
    for row in range(df.shape[0]):
        loc_1 = tuple([df["Origin Latitude"][row],df["Origin Longitude"][row]])
        loc_2 = tuple([df["Destination Latitude"][row],df["Destination Longitude"][row]])
        i = np.where((location_array == loc_1).all(axis=1))[0][0]
        j = np.where((location_array == loc_2).all(axis=1))[0][0]
        val = df[value][row]
        adjacency_matrix[i,j] = df[value][row]
        
    return location_array, adjacency_matrix

# %%
location_array, adjacency_matrix_query = csv_graph("../dataset/dataset.csv")
rows = 0
val = location_array[rows,0]
while location_array[rows,0] == val:
    val = location_array[rows,0]
    rows += 1

# original coordinates
cols = int(location_array.shape[0]/rows)
coordinates_query = initialize_coordinates(adjacency_matrix_query,rows,cols, perturb = .1)
coordinates_query = coordinates_query.reshape((coordinates_query.shape[0] * coordinates_query.shape[1]))

# %%
coordinates_ls, rmse_ls = simulation(adjacency_matrix_query, rows, cols, num_iterations = 11, delta = 1e-3, alpha = 1e-8, kind = 'cubic')
# Out:
# 524.5937226150662

# %%
plt.plot(list(range(len(rmse_ls))), rmse_ls)
plt.ylabel("RMSE")
plt.xlabel("Epoch")
plt.show()

# %%
adjacency_matrix_test = original_adjacency_matrix.copy()
coordinates_test = initialize_coordinates(adjacency_matrix_test,2,2)
print(adjacency_matrix_test)
print(coordinates_test)
# Out:
#   (0, 1)	75.0
#   (0, 2)	50.0
#   (1, 0)	75.0
#   (2, 0)	50.0
#   (3, 0)	50.0
# [[ 0.  0.  0.]
#  [ 0. 60.  0.]
#  [60.  0.  0.]
#  [60. 60.  0.]]

# %%
# same as old code to load in query and dummy set but here for simplicity
location_array = np.array([[ 33.77636,  -84.397824],
                             [ 33.772428, -84.392709],
                             [ 33.77036,  -84.387824],
                             [ 33.765,    -84.38    ]])
# number of vertices
num_vertex = location_array.shape[0]
# this is a numpy matrix of size (num_vertex, num_vertex) which is populated by time between each location
original_adjacency_matrix = lil_matrix((num_vertex,num_vertex), dtype = np.float32)
original_adjacency_matrix[0,1] = 75
original_adjacency_matrix[1,0] = 75
original_adjacency_matrix[0,2] = 50
original_adjacency_matrix[2,0] = 50
original_adjacency_matrix[3,0] = 50
# test dataset
adjacency_matrix_test, row_test, col_test = original_adjacency_matrix, 2, 2

# query
location_array, adjacency_matrix_query = csv_graph("../dataset/dataset.csv")
rows = 0
val = location_array[rows,0]
while location_array[rows,0] == val:
    val = location_array[rows,0]
    rows += 1
cols = int(location_array.shape[0]/rows)
row_query, col_query = rows, cols

# %%
# use scipy because we can't get it to work ourselves
from scipy.optimize import minimize

# choose which of the datasets to use, current query and test
adjacency_matrix, row, col = adjacency_matrix_query, row_query, col_query

# choose which loss function to use
loss, grad = rmse, grad_rmse

# choose how much to perturb when intializing coordinates
pert = .1

# rotate the whole shebang, currently not happening
coordinates = initialize_coordinates(adjacency_matrix, row, col, perturb = pert)
axis = np.array([1,1,1])
theta = 0
rot_mat = rotation_matrix(axis, theta)
plot_coordinates(coordinates, kind = 'linear')
coordinates = np.transpose(rot_mat@np.transpose(coordinates))
#plot_coordinates(coordinates, kind = 'linear')
coordinates = coordinates.reshape((coordinates.shape[0] * coordinates.shape[1]))

r = loss(coordinates, adjacency_matrix)
print(f"Loss Original:    {r}")

print(f"5 Orig Coordinates: {coordinates.reshape((int(coordinates.shape[0]/3), 3))[:5,:]}")

grad_mse(coordinates, adjacency_matrix)
# Out:
# Loss Original:    531.2549847120154
# 5 Orig Coordinates: [[  46.11412885  -57.6129991   -25.16882233]
#  [ -59.12406611  656.90845182  -32.5769424 ]
#  [  22.73633964 1325.68863544  -38.42618395]
#  [ -55.55626849 2046.52332341  100.13330856]
#  [  24.99883234 2853.49436028   17.50933461]]
# array([ 1.51909177e+08, -1.03139707e+09,  1.06934695e+07, ...,
#         6.49137960e+07,  7.19014029e+08, -1.13073064e+08])

# %%
# attempt a first order minimizer
max_iter = 1000
methods = ['BFGS', 'CG', 'L-BFGS-B', 'TNC']
for method in methods:
    s = t.time()
    res = minimize(loss,
                     coordinates,
                     jac = grad,
                     method=method,
                     options={'disp': True,'maxiter': max_iter},
                     args = adjacency_matrix)
    res.x
    new_coordinates = res.x.reshape((int(res.x.shape[0]/3), 3))
    r_new = loss(new_coordinates, adjacency_matrix)
    print(f"Time for Minimization:  {t.time() - s} seconds")
    print(f"Loss after {method}:    {r_new}, fraction: {r_new/r}")
    plot_coordinates(orient_coordinates(new_coordinates))
    print("\n\n\n\n")
# Out:
# ...
#          Current function value: 531.254985
#          Iterations: 0
#          Function evaluations: 84
#          Gradient evaluations: 72
# Time for Minimization:  6.631084442138672 seconds
# Loss after BFGS:    531.2549847120154, fraction: 1.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-ad947890cdaa> in <module>
#      15     print(f"Time for Minimization:  {t.time() - s} seconds")
#      16     print(f"Loss after {method}:    {r_new}, fraction: {r_new/r}")
# ---> 17     plot_coordinates(orient_coordinates(new_coordinates))
#      18     print("\n\n\n\n")
#
# NameError: name 'orient_coordinates' is not defined

# %%
# do minimization with only loss function
max_iter = 20
methods = ['SLSQP']
for method in methods:
    s = t.time()
    res = minimize(mse_dist_squared,
                             coordinates,
                             method=method,
                             options={'disp': True,'maxiter': max_iter},
                             args = adjacency_matrix)
    res.x
    new_coordinates = res.x.reshape((int(res.x.shape[0]/3), 3))
    r_new = rmse(new_coordinates, adjacency_matrix)
    m_new = mse_dist_squared(new_coordinates, adjacency_matrix)
    print(f"Time for Minimization:  {t.time() - s} seconds")
    print(f"RMSE after {method}:    {r_new}, fraction: {r_new/r}")
    print(f"MSE d^2 after {method}: {m_new}, fraction: {m_new/m}")
    plot_coordinates(orient_coordinates(new_coordinates))
# Out:
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 259417635416.51535
#             Iterations: 21
#             Function evaluations: 25347
#             Gradient evaluations: 21
# Time for Minimization:  146.62212133407593 seconds
# RMSE after SLSQP:    210.4372337564184, fraction: 0.4009122410061065
# MSE d^2 after SLSQP: 259417635416.51535, fraction: 0.06754420773153592
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 97.71021135485431
#             Iterations: 25
#             Function evaluations: 177
#             Gradient evaluations: 25
# Best orientation found! axis [4.50600533e-20 6.65351509e-01 7.46530222e-01], theta 0.0016645964921688983

# %%
# run many many many optimizations with the hope of getting a good one

epochs = 50
methods = ['CG']
best_rmse, best_coordinates = np.inf, None

warnings.filterwarnings('ignore')

for epoch in range(epochs):
    coordinates = initialize_coordinates(adjacency_matrix, row, col, perturb = .4)
    for method in methods:
        res = minimize(mse_dist_squared,
                                 coordinates,
                                 jac = grad_mse,
                                 method=method,
                                 options={'disp': True,'maxiter': maxiter},
                                 args = adjacency_matrix)
        new_coordinates = res.x.reshape((int(res.x.shape[0]/3), 3))
        r_new = rmse(new_coordinates, adjacency_matrix)
        if r_new < best_rmse:
            best_rmse, best_coordinates = r_new, new_coordinates
            print(f"Best RMSE: {best_rmse}")
            plot_coordinates(new_coordinates, kind = 'linear')
# Out:
# ...
#          Current function value: 487453443775.310120
#          Iterations: 2
#          Function evaluations: 17
#          Gradient evaluations: 17
# Best RMSE: 347.04816214120973
# ...
#          Current function value: 452333476431.621521
#          Iterations: 2
#          Function evaluations: 18
#          Gradient evaluations: 18
# Best RMSE: 338.2423086991374

# %%
# this function runs a minimization on the coordinates s.t. the average distance from z is minimized,
# note the adj matrix is not changed

def average_z(translation, coordinates):
    axis = translation[:3]
    theta = translation[3]
    rot_mat = rotation_matrix(axis, theta)
    rot_coord = coordinates.copy()
    rot_coord = np.transpose(rot_mat@np.transpose(rot_coord))
    return np.mean(np.abs(rot_coord[:,2]))
    
def orient_coordinates(coordinates, method = 'SLSQP', max_iter = 1000):
    # The first three are the unit vector the third is the rotation
    sqrt_third = (1./3)**.5
    translation = np.array([sqrt_third, sqrt_third, sqrt_third, math.pi])
    res = minimize(average_z,
                     translation,
                     method=method,
                     options={'disp': True,'maxiter': max_iter},
                     args = coordinates,
                     constraints = ({'type': 'eq', 'fun': lambda x:  (x[0]**2 + x[1]**2 + x[2]**2)**.5 - 1.}),
                     bounds = ((0, 1), (0, 1), (0, 1), (0, math.pi*2))
                     )
    print(f"Best orientation found! axis {res.x[:3]}, theta {res.x[3]}")
    axis = res.x[:3]
    theta = res.x[3]
    rot_mat = rotation_matrix(axis, theta)
    rot_coord = coordinates.copy()
    rot_coord = np.transpose(rot_mat@np.transpose(rot_coord))
    return rot_coord

coordinates = new_coordinates

if len(coordinates.shape) == 1:
    coordinates = coordinates.reshape((int(coordinates.shape[0]/3), 3))

# rotate the input
wrong_orientation = coordinates.copy()
# type of rotation
sqrt_third = (1./3)**.5
axis = np.array([sqrt_third,sqrt_third,sqrt_third])
theta = 1
rot_mat = rotation_matrix(axis, theta)
# do the rotation
wrong_orientation = np.transpose(rot_mat@np.transpose(wrong_orientation))
print(f"Original Coords, average z {average_z(np.array([0,0,1,0]),wrong_orientation)}")
plot_coordinates(wrong_orientation)

# find the best orientation!
new_coordinates = orient_coordinates(wrong_orientation)
plot_coordinates(new_coordinates)
# Out:
# Original Coords, average z 2865.5619519637553
# C:\Users\Owner\Anaconda3\lib\site-packages\scipy\interpolate\_fitpack_impl.py:976: RuntimeWarning: No more knots can be added because the number of B-spline
# coefficients already exceeds the number of data points m.
# Probable causes: either s or m too small. (fp>s)
# 	kx,ky=3,3 nx,ny=23,26 m=400 fp=4680283289548.118164 s=0.000000
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 57.35010248679028
#             Iterations: 24
#             Function evaluations: 191
#             Gradient evaluations: 24
# Best orientation found! axis [0.57229715 0.68841441 0.44560396], theta 5.3759953008679116
# C:\Users\Owner\Anaconda3\lib\site-packages\scipy\interpolate\_fitpack_impl.py:976: RuntimeWarning: A theoretically impossible result when finding a smoothing spline
# with fp = s. Probable causes: s too small or badly chosen eps.
# ...

# %%
def save_points(coordinates, adj, csv):
        
    df = pd.read_csv(csv)
    
    locations = set()
    for row in range(df.shape[0]):
        loc = tuple([df["Origin Latitude"][row],df["Origin Longitude"][row]])
        locations.add(loc)
    locations = list(locations)
    
    df_new = pd.DataFrame(locations)
    df_new.columns = ["Latitude", "Longitude"]
    df_new["x"] = coordinates[:,0]
    df_new["y"] = coordinates[:,1]
    df_new["z"] = coordinates[:,2]
    
    df_new.to_csv("../dataset/dataset_coords.csv")

# %%
save_points(new_coordinates, adj_correct_orientation, "../dataset/dataset.csv")
